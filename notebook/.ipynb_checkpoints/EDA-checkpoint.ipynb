# %% [markdown]
# # import python libraries

# %%
import numpy as np
import pandas as pd
import scipy
import os, sys

# %%
# !ls ../Data
# Out:
# 2015-2016 Institution Level Data.xlsx   Field Level Earnings and Debt Data.xlsx
# CollegeScorecardDataDictionary.xlsx     IPEDS_Data

# %%
# !ls ../Data/IPEDS_Data

# %%
# !du -h ../Data//2015-2016\ Institution\ Level\ Data.xlsx
# Out:
#  77M	../Data/2015-2016 Institution Level Data.xlsx

# %%
notebookdir = os.getcwd()
cwd = os.chdir("../Data/")

# %% [markdown]
# # import data

# %% [markdown]
# ## College Scorecard Data Dictionary

# %% [markdown]
# seems like this needs to be cleaned a bit more

# %%
college_scorecard_data = pd.read_excel('CollegeScorecardDataDictionary.xlsx')

# %%
college_scorecard_data.head(50)
# Out:
#   This file provides data descriptions for each data element provided in College Scorecard. Please note that datafiles available in the “Download All Data” provide more data elements and represent a larger universe of institutions than what is presented in the Scorecard consumer page here: collegescorecard.ed.gov. For more information on College Scorecard data, goto https://collegescorecard.ed.gov/data/documentation/
# 0  The "ChangeLog" worksheet describes major chan...
# 1  The “Glossary” worksheet provides definitions ...
# 2  The “institution_data_dictionary” worksheet pr...
# 3  The worksheet named “institution_cohort_map” p...
# 4  The Worksheet named “most_recent_inst_cohort_m...
# 5  The “FieldOfStudy_data_dictionary” worksheet p...
# 6  The worksheet named “FieldOfStudy_cohort_map” ...

# %%
college_scorecard_data.describe()
# Out:
#        This file provides data descriptions for each data element provided in College Scorecard. Please note that datafiles available in the “Download All Data” provide more data elements and represent a larger universe of institutions than what is presented in the Scorecard consumer page here: collegescorecard.ed.gov. For more information on College Scorecard data, goto https://collegescorecard.ed.gov/data/documentation/
# count                                                   7
# unique                                                  7
# top     The “FieldOfStudy_data_dictionary” worksheet p...
# freq                                                    1

# %%
college_scorecard_data.shape

# %% [markdown]
# ## institution level data

# %% [markdown]
# a lot of columns with NaN; may need to remove some columns

# %%
inst_lvl_data = pd.read_excel('2015-2016 Institution Level Data.xlsx')
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  \
# 0     AL       35762           NaN      NaN     NaN
# 1     AL  35294-0110           NaN      NaN     NaN
# 2     AL  36117-3553           NaN      NaN     NaN
# 3     AL       35899           NaN      NaN     NaN
# 4     AL  36104-0271           NaN      NaN     NaN
#
#                ...               OMAWDP8_NOTFIRSTTIME_POOLED_SUPP  \
# 0              ...                                            NaN
# ...

# %%
inst_lvl_data.head(50)
# Out:
#     UNITID    OPEID  OPEID6  \
# 0   100654   100200    1002
# 1   100663   105200    1052
# 2   100690  2503400   25034
# 3   100706   105500    1055
# 4   100724   100500    1005
# 5   100751   105100    1051
# 6   100760   100700    1007
# 7   100812   100800    1008
# 8   100830   831000    8310
# 9   100858   100900    1009
# 10  100937   101200    1012
# 11  101028  1218200   12182
# 12  101073  1055400   10554
# 13  101116  1303906   13039
# 14  101143   101500    1015
# 15  101161   106000    1060
# 16  101189   100300    1003
# 17  101240   101700    1017
# 18  101277  4187200   41872
# 19  101286   101800    1018
# 20  101295   787100    7871
# 21  101301   569900    5699
# 22  101365   962107    9621
# 23  101435   101900    1019
# 24  101453  2199700   21997
# 25  101462   526000    5260
# 26  101480   102000    1020
# 27  101499   102100    1021
# 28  101505   102200    1022
# 29  101514   101300    1013
# 30  101541   102300    1023
# 31  101569   105900    1059
# ...

# %%
inst_lvl_data.describe()
# Out:
#              UNITID         OPEID        OPEID6  ACCREDAGENCY  INSTURL  \
# count  7.593000e+03  7.593000e+03   7593.000000           0.0      0.0
# mean   1.765726e+06  1.910166e+06  16441.276307           NaN      NaN
# std    6.771661e+06  3.516382e+06  14088.868371           NaN      NaN
# min    1.006540e+05  1.002000e+05   1002.000000           NaN      NaN
# 25%    1.752630e+05  3.402000e+05   3395.000000           NaN      NaN
# 50%    2.318730e+05  1.054211e+06  10490.000000           NaN      NaN
# 75%    4.496120e+05  3.010617e+06  26092.000000           NaN      NaN
# max    4.862110e+07  8.209884e+07  42542.000000           NaN      NaN
#
#        NPCURL      SCH_DEG  HCM2         MAIN    NUMBRANCH  \
# count     0.0  7476.000000   0.0  7593.000000  7593.000000
# mean      NaN     1.894061   NaN     0.738312     7.185566
# std       NaN     0.877370   NaN     0.439583    21.184166
# min       NaN     1.000000   NaN     0.000000     1.000000
# ...

# %%
inst_lvl_data.shape
# Out:
# (7593, 1977)

# %% [markdown]
# ## Field level earning and debt data

# %% [markdown]
# looks like this dataset is the most complete out of the data so far, although we may need to drop rows that have privacy suppressed.

# %%
field_lvl_data = pd.read_excel('Field Level Earnings and Debt Data.xlsx')

# %%
field_lvl_data.head(100)
# Out:
#       UNITID  OPEID6                               INSTNM CONTROL  MAIN  \
# 0   100654.0    1002             Alabama A & M University  Public     1
# 1   100654.0    1002             Alabama A & M University  Public     1
# 2   100654.0    1002             Alabama A & M University  Public     1
# 3   100654.0    1002             Alabama A & M University  Public     1
# 4   100654.0    1002             Alabama A & M University  Public     1
# 5   100654.0    1002             Alabama A & M University  Public     1
# 6   100654.0    1002             Alabama A & M University  Public     1
# 7   100654.0    1002             Alabama A & M University  Public     1
# 8   100654.0    1002             Alabama A & M University  Public     1
# 9   100654.0    1002             Alabama A & M University  Public     1
# 10  100654.0    1002             Alabama A & M University  Public     1
# 11  100654.0    1002             Alabama A & M University  Public     1
# ...

# %%
field_lvl_data.describe()
# Out:
#               UNITID         OPEID6           MAIN        CIPCODE  \
# count  211020.000000  216638.000000  216638.000000  216638.000000
# mean   205021.418396    6797.829905       0.934005    3355.370706
# std     89384.634211    9075.099824       0.248274    1709.082327
# min    100654.000000    1002.000000       0.000000     100.000000
# 25%    150534.000000    2071.000000       1.000000    1500.000000
# 50%    188261.000000    3208.000000       1.000000    4005.000000
# 75%    222567.000000    6810.000000       1.000000    5107.000000
# max    491394.000000   42817.000000       1.000000    6005.000000
#
#              CREDLEV    IPEDSCOUNT1    IPEDSCOUNT2  Monthly Earnings  \
# count  216638.000000  183767.000000  186139.000000        251.000000
# mean        3.156182      27.653360      27.603415       5537.682603
# std         1.849397      87.537575      89.371851       1849.187498
# min         1.000000       0.000000       0.000000       1516.670000
# ...

# %%
field_lvl_data.shape
# Out:
# (216638, 20)
